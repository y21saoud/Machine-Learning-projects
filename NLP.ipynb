# %%
import seaborn as sns
import nltk
import spacy
from matplotlib import pyplot as plt
import pandas as pd
from wordcloud import WordCloud

nltk.download('stopwords')
nlp = spacy.load('en_core_web_sm')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
texte = "Homer Jay Simpson is a fictional character and one of the main protagonists of the American animated sitcom The Simpsons. He is voiced by Dan Castellaneta and first appeared on television, along with the rest of his family, in The Tracey Ullman Show short \"Good Night\" on April 19, 1987. Homer was created and designed by cartoonist Matt Groening while he was waiting in the lobby of James L. Brooks' office. Groening had been called to pitch a series of shorts based on his comic strip Life in Hell but instead decided to create a new set of characters. He named the character after his father, Homer Groening. After appearing for three seasons on The Tracey Ullman Show, the Simpson family got their own series on Fox, which debuted December 17, 1989.\
As patriarch of the eponymous family, Homer and his wife Marge have three children: Bart, Lisa and Maggie. As the family's provider, he works at the Springfield Nuclear Power Plant as safety inspector. Homer embodies many American working class stereotypes: he is obese, immature, outspoken, aggressive, balding, lazy, ignorant, unprofessional, and addicted to beer, junk food and watching television. However, he is fundamentally a good man and is staunchly protective of his family, especially when they need him the most. Despite the suburban blue-collar routine of his life, he has had a number of remarkable experiences, including going to space, climbing the tallest mountain in Springfield by himself, fighting former President George H. W. Bush and winning a Grammy Award as a member of a barbershop quartet.\
In the shorts and earlier episodes, Castellaneta voiced Homer with a loose impression of Walter Matthau; however, during the second and third seasons of the half-hour show, Homer's voice evolved to become more robust, to allow the expression of a fuller range of emotions. He has appeared in other media relating to The Simpsons—including video games, The Simpsons Movie, The Simpsons Ride, commercials, and comic books—and inspired an entire line of merchandise. His signature catchphrase, the annoyed grunt \"D'oh!\", has been included in The New Oxford Dictionary of English since 1998 and the Oxford English Dictionary since 2001.\
Homer is one of the most influential characters in the history of television, and is widely considered to be an American cultural icon. The British newspaper The Sunday Times described him as \"The greatest comic creation of [modern] time\". He was named the greatest character \"of the last 20 years\" in 2010 by Entertainment Weekly, was ranked the second-greatest cartoon character by TV Guide, behind Bugs Bunny, and was voted the greatest television character of all time by Channel 4 viewers. For voicing Homer, Castellaneta has won four Primetime Emmy Awards for Outstanding Voice-Over Performance and a special-achievement Annie Award. In 2000, Homer and his family were awarded a star on the Hollywood Walk of Fame. "

texte
# Out:
# 'Homer Jay Simpson is a fictional character and one of the main protagonists of the American animated sitcom The Simpsons. He is voiced by Dan Castellaneta and first appeared on television, along with the rest of his family, in The Tracey Ullman Show short "Good Night" on April 19, 1987. Homer was created and designed by cartoonist Matt Groening while he was waiting in the lobby of James L. Brooks\' office. Groening had been called to pitch a series of shorts based on his comic strip Life in Hell but instead decided to create a new set of characters. He named the character after his father, Homer Groening. After appearing for three seasons on The Tracey Ullman Show, the Simpson family got their own series on Fox, which debuted December 17, 1989.As patriarch of the eponymous family, Homer and his wife Marge have three children: Bart, Lisa and Maggie. As the family\'s provider, he works at the Springfield Nuclear Power Plant as safety inspector. Homer embodies many American working class stereotypes: he is obese, immature, outspoken, aggressive, balding, lazy, ignorant, unprofessional, and addicted to beer, junk food and watching television. However, he is fundamentally a good man and is staunchly protective of his family, especially when they need him the most. Despite the suburban blue-collar routine of his life, he has had a number of remarkable experiences, including going to space, climbing the tallest mountain in Springfield by himself, fighting former President George H. W. Bush and winning a Grammy Award as a member of a barbershop quartet.In the shorts and earlier episodes, Castellaneta voiced Homer with a loose impression of Walter Matthau; however, during the second and third seasons of the half-hour show, Homer\'s voice evolved to become more robust, to allow the expression of a fuller range of emotions. He has appeared in other media relating to The Simpsons—including video games, The Simpsons Movie, The Simpsons Ride, commercials, and comic books—and inspired an entire line of merchandise. His signature catchphrase, the annoyed grunt "D\'oh!", has been included in The New Oxford Dictionary of English since 1998 and the Oxford English Dictionary since 2001.Homer is one of the most influential characters in the history of television, and is widely considered to be an American cultural icon. The British newspaper The Sunday Times described him as "The greatest comic creation of [modern] time". He was named the greatest character "of the last 20 years" in 2010 by Entertainment Weekly, was ranked the second-greatest cartoon character by TV Guide, behind Bugs Bunny, and was voted the greatest television character of all time by Channel 4 viewers. For voicing Homer, Castellaneta has won four Primetime Emmy Awards for Outstanding Voice-Over Performance and a special-achievement Annie Award. In 2000, Homer and his family were awarded a star on the Hollywood Walk of Fame. '

# %%
phrases = [p.strip() for p in texte.split('.') if len(p)>2]
phrases
# Out:
# ['Homer Jay Simpson is a fictional character and one of the main protagonists of the American animated sitcom The Simpsons',
#  'He is voiced by Dan Castellaneta and first appeared on television, along with the rest of his family, in The Tracey Ullman Show short "Good Night" on April 19, 1987',
#  'Homer was created and designed by cartoonist Matt Groening while he was waiting in the lobby of James L',
#  "Brooks' office",
#  'Groening had been called to pitch a series of shorts based on his comic strip Life in Hell but instead decided to create a new set of characters',
#  'He named the character after his father, Homer Groening',
#  'After appearing for three seasons on The Tracey Ullman Show, the Simpson family got their own series on Fox, which debuted December 17, 1989',
#  'As patriarch of the eponymous family, Homer and his wife Marge have three children: Bart, Lisa and Maggie',
#  "As the family's provider, he works at the Springfield Nuclear Power Plant as safety inspector",
#  'Homer embodies many American working class stereotypes: he is obese, immature, outspoken, aggressive, balding, lazy, ignorant, unprofessional, and addicted to beer, junk food and watching television',
#  'However, he is fundamentally a good man and is staunchly protective of his family, especially when they need him the most',
#  'Despite the suburban blue-collar routine of his life, he has had a number of remarkable experiences, including going to space, climbing the tallest mountain in Springfield by himself, fighting former President George H',
#  'Bush and winning a Grammy Award as a member of a barbershop quartet',
#  "In the shorts and earlier episodes, Castellaneta voiced Homer with a loose impression of Walter Matthau; however, during the second and third seasons of the half-hour show, Homer's voice evolved to become more robust, to allow the expression of a fuller range of emotions",
#  'He has appeared in other media relating to The Simpsons—including video games, The Simpsons Movie, The Simpsons Ride, commercials, and comic books—and inspired an entire line of merchandise',
#  'His signature catchphrase, the annoyed grunt "D\'oh!", has been included in The New Oxford Dictionary of English since 1998 and the Oxford English Dictionary since 2001',
#  'Homer is one of the most influential characters in the history of television, and is widely considered to be an American cultural icon',
#  'The British newspaper The Sunday Times described him as "The greatest comic creation of [modern] time"',
#  'He was named the greatest character "of the last 20 years" in 2010 by Entertainment Weekly, was ranked the second-greatest cartoon character by TV Guide, behind Bugs Bunny, and was voted the greatest television character of all time by Channel 4 viewers',
#  'For voicing Homer, Castellaneta has won four Primetime Emmy Awards for Outstanding Voice-Over Performance and a special-achievement Annie Award',
#  'In 2000, Homer and his family were awarded a star on the Hollywood Walk of Fame']

# %%
liste_mots = []
for p in phrases :
  for m in p.split() :
    liste_mots.append(m)

liste_mots
# Out:
# ['Homer',
#  'Jay',
#  'Simpson',
#  'is',
#  'a',
#  'fictional',
#  'character',
#  'and',
#  'one',
#  'of',
#  'the',
#  'main',
#  'protagonists',
#  'of',
#  'the',
#  'American',
#  'animated',
#  'sitcom',
#  'The',
#  'Simpsons',
#  'He',
#  'is',
#  'voiced',
#  'by',
#  'Dan',
#  'Castellaneta',
#  'and',
#  'first',
#  'appeared',
#  'on',
#  'television,',
#  'along',
#  'with',
#  'the',
#  'rest',
#  'of',
#  'his',
#  'family,',
#  'in',
#  'The',
#  'Tracey',
#  'Ullman',
#  'Show',
#  'short',
#  '"Good',
#  'Night"',
#  'on',
#  'April',
#  '19,',
#  '1987',
#  'Homer',
#  'was',
#  'created',
#  'and',
#  'designed',
#  'by',
#  'cartoonist',
#  'Matt',
#  'Groening',
#  'while',
#  'he',
#  'was',
#  'waiting',
#  'in',
#  'the',
#  'lobby',
#  'of',
#  'James',
#  'L',
#  "Brooks'",
#  'office',
#  'Groening',
#  'had',
#  'been',
#  'called',
#  'to',
#  'pitch',
#  'a',
#  'series',
#  'of',
#  'shorts',
#  'based',
#  'on',
#  'his',
#  'comic',
#  'strip',
#  'Life',
#  'in',
#  'Hell',
#  'but',
#  'instead',
#  'decided',
#  'to',
#  'create',
#  'a',
#  'new',
#  'set',
#  'of',
#  'characters',
#  'He',
#  'named',
#  'the',
#  'character',
#  'after',
#  'his',
#  'father,',
#  'Homer',
#  'Groening',
#  'After',
#  'appearing',
#  'for',
#  'three',
#  'seasons',
#  'on',
#  'The',
#  'Tracey',
#  'Ullman',
#  'Show,',
#  'the',
#  'Simpson',
#  'family',
#  'got',
#  'their',
#  'own',
#  'series',
#  'on',
#  'Fox,',
#  'which',
#  'debuted',
#  'December',
#  '17,',
#  '1989',
#  'As',
#  'patriarch',
#  'of',
#  'the',
#  'eponymous',
#  'family,',
#  'Homer',
#  'and',
#  'his',
#  'wife',
#  'Marge',
#  'have',
#  'three',
#  'children:',
#  'Bart,',
#  'Lisa',
#  'and',
#  'Maggie',
#  'As',
#  'the',
#  "family's",
#  'provider,',
#  'he',
#  'works',
#  'at',
#  'the',
#  'Springfield',
#  'Nuclear',
#  'Power',
#  'Plant',
#  'as',
#  'safety',
#  'inspector',
#  'Homer',
#  'embodies',
#  'many',
#  'American',
#  'working',
#  'class',
#  'stereotypes:',
#  'he',
#  'is',
#  'obese,',
#  'immature,',
#  'outspoken,',
#  'aggressive,',
#  'balding,',
#  'lazy,',
#  'ignorant,',
#  'unprofessional,',
#  'and',
#  'addicted',
#  'to',
#  'beer,',
#  'junk',
#  'food',
#  'and',
#  'watching',
#  'television',
#  'However,',
#  'he',
#  'is',
#  'fundamentally',
#  'a',
#  'good',
#  'man',
#  'and',
#  'is',
#  'staunchly',
#  'protective',
#  'of',
#  'his',
#  'family,',
#  'especially',
#  'when',
#  'they',
#  'need',
#  'him',
#  'the',
#  'most',
#  'Despite',
#  'the',
#  'suburban',
#  'blue-collar',
#  'routine',
#  'of',
#  'his',
#  'life,',
#  'he',
#  'has',
#  'had',
#  'a',
#  'number',
#  'of',
#  'remarkable',
#  'experiences,',
#  'including',
#  'going',
#  'to',
#  'space,',
#  'climbing',
#  'the',
#  'tallest',
#  'mountain',
#  'in',
#  'Springfield',
#  'by',
#  'himself,',
#  'fighting',
#  'former',
#  'President',
#  'George',
#  'H',
#  'Bush',
#  'and',
#  'winning',
#  'a',
#  'Grammy',
#  'Award',
#  'as',
#  'a',
#  'member',
#  'of',
#  'a',
#  'barbershop',
#  'quartet',
#  'In',
#  'the',
#  'shorts',
#  'and',
#  'earlier',
#  'episodes,',
#  'Castellaneta',
#  'voiced',
#  'Homer',
#  'with',
#  'a',
#  'loose',
#  'impression',
#  'of',
#  'Walter',
#  'Matthau;',
#  'however,',
#  'during',
#  'the',
#  'second',
#  'and',
#  'third',
#  'seasons',
#  'of',
#  'the',
#  'half-hour',
#  'show,',
#  "Homer's",
#  'voice',
#  'evolved',
#  'to',
#  'become',
#  'more',
#  'robust,',
#  'to',
#  'allow',
#  'the',
#  'expression',
#  'of',
#  'a',
#  'fuller',
#  'range',
#  'of',
#  'emotions',
#  'He',
#  'has',
#  'appeared',
#  'in',
#  'other',
#  'media',
#  'relating',
#  'to',
#  'The',
#  'Simpsons—including',
#  'video',
#  'games,',
#  'The',
#  'Simpsons',
#  'Movie,',
#  'The',
#  'Simpsons',
#  'Ride,',
#  'commercials,',
#  'and',
#  'comic',
#  'books—and',
#  'inspired',
#  'an',
#  'entire',
#  'line',
#  'of',
#  'merchandise',
#  'His',
#  'signature',
#  'catchphrase,',
#  'the',
#  'annoyed',
#  'grunt',
#  '"D\'oh!",',
#  'has',
#  'been',
#  'included',
#  'in',
#  'The',
#  'New',
#  'Oxford',
#  'Dictionary',
#  'of',
#  'English',
#  'since',
#  '1998',
#  'and',
#  'the',
#  'Oxford',
#  'English',
#  'Dictionary',
#  'since',
#  '2001',
#  'Homer',
#  'is',
#  'one',
#  'of',
#  'the',
#  'most',
#  'influential',
#  'characters',
#  'in',
#  'the',
#  'history',
#  'of',
#  'television,',
#  'and',
#  'is',
#  'widely',
#  'considered',
#  'to',
#  'be',
#  'an',
#  'American',
#  'cultural',
#  'icon',
#  'The',
#  'British',
#  'newspaper',
#  'The',
#  'Sunday',
#  'Times',
#  'described',
#  'him',
#  'as',
#  '"The',
#  'greatest',
#  'comic',
#  'creation',
#  'of',
#  '[modern]',
#  'time"',
#  'He',
#  'was',
#  'named',
#  'the',
#  'greatest',
#  'character',
#  '"of',
#  'the',
#  'last',
#  '20',
#  'years"',
#  'in',
#  '2010',
#  'by',
#  'Entertainment',
#  'Weekly,',
#  'was',
#  'ranked',
#  'the',
#  'second-greatest',
#  'cartoon',
#  'character',
#  'by',
#  'TV',
#  'Guide,',
#  'behind',
#  'Bugs',
#  'Bunny,',
#  'and',
#  'was',
#  'voted',
#  'the',
#  'greatest',
#  'television',
#  'character',
#  'of',
#  'all',
#  'time',
#  'by',
#  'Channel',
#  '4',
#  'viewers',
#  'For',
#  'voicing',
#  'Homer,',
#  'Castellaneta',
#  'has',
#  'won',
#  'four',
#  'Primetime',
#  'Emmy',
#  'Awards',
#  'for',
#  'Outstanding',
#  'Voice-Over',
#  'Performance',
#  'and',
#  'a',
#  'special-achievement',
#  'Annie',
#  'Award',
#  'In',
#  '2000,',
#  'Homer',
#  'and',
#  'his',
#  'family',
#  'were',
#  'awarded',
#  'a',
#  'star',
#  'on',
#  'the',
#  'Hollywood',
#  'Walk',
#  'of',
#  'Fame']

# %%
pd.Series(liste_mots).value_counts()[:50]
# Out:
# the             25
# of              22
# and             17
# a               12
# The              9
# Homer            8
# to               8
# in               8
# is               7
# his              7
# on               6
# by               6
# was              5
# he               5
# character        5
# has              4
# He               4
# Castellaneta     3
# family,          3
# comic            3
# Groening         3
# greatest         3
# as               3
# Simpsons         3
# American         3
# been             2
# had              2
# for              2
# In               2
# series           2
# shorts           2
# characters       2
# named            2
# Award            2
# television       2
# three            2
# an               2
# family           2
# As               2
# since            2
# English          2
# most             2
# Dictionary       2
# Springfield      2
# him              2
# Oxford           2
# seasons          2
# Ullman           2
# voiced           2
# Simpson          2
# dtype: int64

# %%
plt.figure(figsize=(20,10))
freq = pd.Series(liste_mots).value_counts()[:10]

sns.barplot(freq.index, freq.values)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#nettoyage du texte
def nettoyage(phrase):
  p=''
  for element in phrase :
    if element not in [',','.','"','?','!','\\','/',';','-','_'] :
      p += element.lower()

  return p

# %%
mot_communs = nltk.corpus.stopwords.words('english')

# %%
liste_mots_propres = [nettoyage(mot) for mot in liste_mots]
liste_mots_propres = [mot for mot in liste_mots_propres if mot not in mot_communs]
#liste_mots_propres

# %%
plt.figure(figsize=(20,10))
freq = pd.Series(liste_mots_propres).value_counts()[:10]

sns.barplot(freq.index, freq.values)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
exemple_tokens = nlp(' '.join(['am','running','ran','computed',]))
exemple_tokens[0].lemma_,exemple_tokens[1].lemma_,exemple_tokens[2].lemma_,exemple_tokens[3].lemma_
# Out:
# ('be', 'run', 'run', 'compute')

# %%
tokens_liste_propre = nlp(' '.join(liste_mots_propres))
racines_mots = []

for mot in tokens_liste_propre :
  racines_mots.append(mot.lemma_)

racines_mots
# Out:
# ['homer',
#  'jay',
#  'simpson',
#  'fictional',
#  'character',
#  'one',
#  'main',
#  'protagonist',
#  'american',
#  'animate',
#  'sitcom',
#  'simpson',
#  'voice',
#  'dan',
#  'castellaneta',
#  'first',
#  'appear',
#  'television',
#  'along',
#  'rest',
#  'family',
#  'tracey',
#  'ullman',
#  'show',
#  'short',
#  'good',
#  'night',
#  'april',
#  '19',
#  '1987',
#  'homer',
#  'create',
#  'design',
#  'cartoonist',
#  'matt',
#  'groene',
#  'wait',
#  'lobby',
#  'james',
#  'l',
#  'brooks',
#  "'",
#  'office',
#  'groene',
#  'call',
#  'pitch',
#  'series',
#  'short',
#  'base',
#  'comic',
#  'strip',
#  'life',
#  'hell',
#  'instead',
#  'decide',
#  'create',
#  'new',
#  'set',
#  'character',
#  'name',
#  'character',
#  'father',
#  'homer',
#  'groene',
#  'appear',
#  'three',
#  'season',
#  'tracey',
#  'ullman',
#  'show',
#  'simpson',
#  'family',
#  'get',
#  'series',
#  'fox',
#  'debut',
#  'december',
#  '17',
#  '1989',
#  'patriarch',
#  'eponymous',
#  'family',
#  'homer',
#  'wife',
#  'marge',
#  'three',
#  'child',
#  ':',
#  'bart',
#  'lisa',
#  'maggie',
#  'family',
#  "'s",
#  'provider',
#  'work',
#  'springfield',
#  'nuclear',
#  'power',
#  'plant',
#  'safety',
#  'inspector',
#  'homer',
#  'embody',
#  'many',
#  'american',
#  'working',
#  'class',
#  'stereotype',
#  ':',
#  'obese',
#  'immature',
#  'outspoken',
#  'aggressive',
#  'balding',
#  'lazy',
#  'ignorant',
#  'unprofessional',
#  'addicted',
#  'beer',
#  'junk',
#  'food',
#  'watch',
#  'television',
#  'however',
#  'fundamentally',
#  'good',
#  'man',
#  'staunchly',
#  'protective',
#  'family',
#  'especially',
#  'need',
#  'despite',
#  'suburban',
#  'bluecollar',
#  'routine',
#  'life',
#  'number',
#  'remarkable',
#  'experience',
#  'include',
#  'go',
#  'space',
#  'climb',
#  'tall',
#  'mountain',
#  'springfield',
#  'fight',
#  'former',
#  'president',
#  'george',
#  'h',
#  'bush',
#  'win',
#  'grammy',
#  'award',
#  'member',
#  'barbershop',
#  'quartet',
#  'short',
#  'early',
#  'episode',
#  'castellaneta',
#  'voice',
#  'homer',
#  'loose',
#  'impression',
#  'walter',
#  'matthau',
#  'however',
#  'second',
#  'third',
#  'season',
#  'halfhour',
#  'show',
#  'homer',
#  "'s",
#  'voice',
#  'evolve',
#  'become',
#  'robust',
#  'allow',
#  'expression',
#  'fuller',
#  'range',
#  'emotion',
#  'appear',
#  'medium',
#  'relate',
#  'simpson',
#  '—',
#  'include',
#  'video',
#  'game',
#  'simpson',
#  'movie',
#  'simpson',
#  'ride',
#  'commercial',
#  'comic',
#  'book',
#  '—',
#  'and',
#  'inspire',
#  'entire',
#  'line',
#  'merchandise',
#  'signature',
#  'catchphrase',
#  'annoyed',
#  'grunt',
#  "d'oh",
#  'include',
#  'new',
#  'oxford',
#  'dictionary',
#  'english',
#  'since',
#  '1998',
#  'oxford',
#  'english',
#  'dictionary',
#  'since',
#  '2001',
#  'homer',
#  'one',
#  'influential',
#  'character',
#  'history',
#  'television',
#  'widely',
#  'consider',
#  'american',
#  'cultural',
#  'icon',
#  'british',
#  'newspaper',
#  'sunday',
#  'times',
#  'describe',
#  'great',
#  'comic',
#  'creation',
#  '[',
#  'modern',
#  ']',
#  'time',
#  'name',
#  'great',
#  'character',
#  'last',
#  '20',
#  'year',
#  '2010',
#  'entertainment',
#  'weekly',
#  'rank',
#  'secondgreat',
#  'cartoon',
#  'character',
#  'tv',
#  'guide',
#  'behind',
#  'bug',
#  'bunny',
#  'vote',
#  'great',
#  'television',
#  'character',
#  'time',
#  'channel',
#  '4',
#  'viewer',
#  'voice',
#  'homer',
#  'castellaneta',
#  'four',
#  'primetime',
#  'emmy',
#  'award',
#  'outstanding',
#  'voiceover',
#  'performance',
#  'specialachievement',
#  'annie',
#  'award',
#  '2000',
#  'homer',
#  'family',
#  'award',
#  'star',
#  'hollywood',
#  'walk',
#  'fame']

# %%
plt.figure(figsize=(20,10))
freq = pd.Series(racines_mots).value_counts()[:10]

sns.barplot(freq.index, freq.values)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
texte_propre = ' '.join(racines_mots)

nuage_mots = WordCloud(width = 1000, height=1000)
nuage_mots.generate_from_text(texte_propre)

plt.figure(figsize = (20,10))
plt.imshow(nuage_mots)
plt.axis('off')
plt.margins(x=0,y=0)
plt.show()

# %%
WordCloud.to_file(nuage_mots,'nuage.jpg')
